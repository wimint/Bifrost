# %%
import json
file = open("/Users/wmt/Library/CloudStorage/OneDrive-NovoNordisk/Code Repository/UKBiobank-Bifrost/Mar_2025/dhukbb53639xggxe5eucentral1-march_2025.json", "r")
data = json.load(file)
print(data)
# Out:
# {'events': [{'timestamp': 1743432600933, 'message': '{"sourceAddress":"10.32.164.83","clientUid":"278890426","source":"share-EBB12397","type":"FileSystemAudit","version":"1.0","objectType":"File","bucket":"dhukbb53639xggxe5eucentral1","clientGid":"1432000513","objectName":"/Derived/WGS_500K_site_only/annotation.vcf.gz","shareName":"/dhukbb53639xggxe5eucentral1","operation":"ReadData","gateway":"sgw-EAD00183","timestamp":"1743432600933","status":"Success"}', 'ingestionTime': 1743432630485}, {'timestamp': 1743432601952, 'message': '{"sourceAddress":"10.32.164.83","clientUid":"278890426","source":"share-EBB12397","type":"FileSystemAudit","version":"1.0","objectType":"File","bucket":"dhukbb53639xggxe5eucentral1","clientGid":"1432000513","objectName":"/Derived/WGS_500K_site_only/annotation.vcf.gz","shareName":"/dhukbb53639xggxe5eucentral1","operation":"ReadData","gateway":"sgw-EAD00183","timestamp":"1743432601952","status":"Success"}', 'ingestionTime': 1743432630485}, {'timestamp': 174343
# ...

# %%
import pandas as pd
df = pd.DataFrame(data["events"])
df = df.drop("ingestionTime",axis=1)
df.head()
df.to_csv("/Users/wmt/Library/CloudStorage/OneDrive-NovoNordisk/Code Repository/UKBiobank-Bifrost/Mar_2025/UKBB53639__mar_2025.csv", index=False)
